# %%
# %%writefile mytextfile.txt
#
# This is the 1st line
# This is the 2st line
# This is the 3st line
# This is the 4st line
# Out:
# Writing mytextfile.txt

# %%
my_file = open('mytextfile.txt')

# %%
my_file.read()
# Out:
# '\nThis is the 1st line\nThis is the 2st line\nThis is the 3st line\nThis is the 4st line\n'

# %%
my_file.read()
# Out:
# ''

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.read()
# Out:
# '\nThis is the 1st line\nThis is the 2st line\nThis is the 3st line\nThis is the 4st line\n'

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.readlines()
# Out:
# ['\n',
#  'This is the 1st line\n',
#  'This is the 2st line\n',
#  'This is the 3st line\n',
#  'This is the 4st line\n']

# %%
my_file.close()

# %%
# new way to read the file 
with open('mytextfile.txt') as my_new_file:
    contents = my_new_file.readlines()

# %%
contents
# Out:
# ['\n',
#  'This is the 1st line\n',
#  'This is the 2st line\n',
#  'This is the 3st line\n',
#  'This is the 4st line\n']

# %% [markdown]
# ![Screenshot%202024-11-24%20114202.png](attachment:Screenshot%202024-11-24%20114202.png)

# %% [markdown]
# # Mode = r

# %%
with open('mytextfile.txt', mode='r') as myfile:
    contents = myfile.read()

# %%
contents
# Out:
# '\nThis is the 1st line\nThis is the 2st line\nThis is the 3st line\nThis is the 4st line\n'

# %%
# %%writefile my_new_file.txt
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
# Out:
# Writing my_new_file.txt

# %%
with open('my_new_file.txt', mode='r') as f:
    print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD

# %%
with open('my_new_file.txt', mode='a') as f:
    f.write('FOUR ON FOURTH')

# %%
with open('my_new_file.txt', mode='r') as f:
    print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
# FOUR ON FOURTH
