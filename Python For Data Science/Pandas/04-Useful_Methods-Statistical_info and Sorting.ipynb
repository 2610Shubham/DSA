# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# # **`.describe()`**
#
# The `.describe()` method in Pandas generates summary statistics for numerical and categorical data in a DataFrame or Series. It is a quick way to understand the distribution and key statistics of your data.
#
# ---

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df[['total_bill', 'tip', 'size', 'price_per_person']].describe()
# Out:
#        total_bill         tip        size  price_per_person
# count  244.000000  244.000000  244.000000        244.000000
# mean    19.785943    2.998279    2.569672          7.888197
# std      8.902412    1.383638    0.951100          2.914234
# min      3.070000    1.000000    1.000000          2.880000
# 25%     13.347500    2.000000    2.000000          5.800000
# 50%     17.795000    2.900000    2.000000          7.255000
# 75%     24.127500    3.562500    3.000000          9.390000
# max     50.810000   10.000000    6.000000         20.270000

# %%
df[['total_bill', 'tip', 'size', 'price_per_person']].describe().transpose()
# Out:
#                   count       mean       std   min      25%     50%      75%  \
# total_bill        244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275
# tip               244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625
# size              244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000
# price_per_person  244.0   7.888197  2.914234  2.88   5.8000   7.255   9.3900
#
#                     max
# total_bill        50.81
# tip               10.00
# size               6.00
# price_per_person  20.27

# %% [markdown]
# # **`.sort_values()` in Pandas**
#
# The `.sort_values()` method in Pandas is used to sort a DataFrame or Series based on the values of one or more columns. It allows sorting in ascending or descending order and provides options for handling missing data and customizing sorting behavior.

# %%
df.sort_values('tip') # Sort the df based on the tip column
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.sort_values('tip', ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
#
#              Payer Name         CC Number Payment ID
# ...

# %%
# Sort the df by using the multiple columns 
df.sort_values(['tip', 'size'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df['total_bill'].max()
# Out:
# 50.81

# %% [markdown]
# ### Grabe the index location of the max value & min value

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df['total_bill'].idxmin()
# Out:
# 67

# %%
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Name: 170, dtype: object

# %%
df.iloc[67]
# Out:
# total_bill                      3.07
# tip                              1.0
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# Name: 67, dtype: object

# %% [markdown]
# # **`.corr()`**
#
# The `.corr()` method in Pandas computes pairwise correlation coefficients between numerical columns in a DataFrame. It measures the strength and direction of linear relationships between variables, with values ranging from `-1` (strong negative correlation) to `1` (strong positive correlation). A value of `0` indicates no linear correlation.

# %%
df.corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %% [markdown]
# # **`.value_counts()`**
#
# The `.value_counts()` method is used to count the occurrences of unique values in a Series. It returns a Series where the index represents the unique values, and the corresponding values are their respective counts, sorted in descending order by default.

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %% [markdown]
# # **`.unique()`**
#
# The `.unique()` method returns the unique values in a Series or the unique values within each column of a DataFrame. It outputs a NumPy array of distinct elements, preserving the order of their appearance.

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %% [markdown]
# # **`.nunique()`**
#
# The `.nunique()` method returns the number of unique values in a Series or, for a DataFrame, the number of unique values in each column. It can optionally include or exclude `NaN` values in the count.

# %%
df['day'].nunique()
# Out:
# 4

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# # **`.replace()`**
#
# The `.replace()` method is used to replace specified values in a Series or DataFrame with new values. It supports replacing single values, lists, dictionaries, or patterns using regular expressions, providing flexibility for data cleaning and transformation tasks.

# %%
df['sex'].replace(to_replace='Female', value='F')
# Out:
# 0         F
# 1      Male
# 2      Male
# 3      Male
# 4         F
#        ...
# 239    Male
# 240       F
# 241    Male
# 242    Male
# 243       F
# Name: sex, Length: 244, dtype: object

# %%
df['sex'].replace( ['Female' , 'Male'], ['F','M'] )
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %% [markdown]
# # **`.map()`**
#
# The `.map()` method is used to transform each element in a Pandas Series by applying a function, dictionary, or Series. It is commonly used for element-wise operations, value replacements, or applying custom logic to modify the data.

# %%
mymap = {'Female': 'F', 
         'Male': 'M'
        }

# %%
df['sex'].map(mymap)
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %% [markdown]
# # **`.duplicated()`**
#
# The `.duplicated()` method identifies duplicate rows in a DataFrame or duplicate elements in a Series. It returns a boolean Series indicating whether each row or element is a duplicate, with options to specify how duplicates are considered (e.g., first occurrence, last occurrence).

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
# Creating a sample data set to check it 
sample_df = pd.DataFrame([1,2,3,3,3],['a','b','c','d','e'])

# %%
sample_df
# Out:
#    0
# a  1
# b  2
# c  3
# d  3
# e  3

# %%
sample_df.duplicated()
# Out:
# a    False
# b    False
# c    False
# d     True
# e     True
# dtype: bool

# %% [markdown]
# # **`drop_duplicates()`**
#
# The `drop_duplicates()` method removes duplicate rows from a DataFrame or duplicate elements from a Series. It provides options to specify which columns to consider for duplicates and whether to keep the first or last occurrence of each duplicate, or to drop all duplicates entirely.

# %%
sample_df.drop_duplicates(inplace=True)

# %%
sample_df
# Out:
#    0
# a  1
# b  2
# c  3

# %% [markdown]
# # **`.between()`**
#
# The `.between()` method checks whether each value in a Series lies within a specified range. It returns a boolean Series where `True` indicates the value is within the range, inclusive of the boundary values by default.

# %%
df['total_bill'].between(10,20, inclusive=True)
# Out:
# C:\Users\SHUBHAM\AppData\Local\Temp\ipykernel_25352\2659872724.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df['total_bill'].between(10,20, inclusive=True)
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df['total_bill'].between(10, 20, inclusive=True)]
# Out:
# C:\Users\SHUBHAM\AppData\Local\Temp\ipykernel_25352\75008346.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df[df['total_bill'].between(10, 20, inclusive=True)]
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 9         14.78  3.23    Male     No   Sun  Dinner     2              7.39
# 10        10.27  1.71    Male     No   Sun  Dinner     2              5.14
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# ...

# %% [markdown]
# ###  WAP to find the first 10 largest tips

# %% [markdown]
# # **`.nlargest()`**
#
# The `.nlargest()` method returns the specified number of rows with the largest values in a Series or DataFrame column. It is commonly used for quickly identifying top values based on a specific criterion.

# %%
df.nlargest(10, 'tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4              5.79
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3              9.39
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 239       29.03   5.92    Male     No   Sat  Dinner     3              9.68
# 88        24.71   5.85    Male     No  Thur   Lunch     2             12.36
#
#             Payer Name         CC Number Payment ID
# 170      Gregory Clark  5473850968388236    Sat1954
# ...

# %% [markdown]
# # **`.nsmallest()`**
#
# The `.nsmallest()` method returns the first `n` smallest values from a DataFrame or Series. It sorts the data in ascending order and returns the corresponding rows or elements.

# %%
df.nsmallest(10, 'tip')
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25  1.00  Female     No   Sat  Dinner     1              7.25
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2              6.45
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 75        10.51  1.25    Male     No   Sat  Dinner     2              5.26
# 135        8.51  1.25  Female     No  Thur   Lunch     2              4.26
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
#
#              Payer Name         CC Number Payment ID
# 67        Tiffany Brock  4359488526995267    Sat3455
# ...

# %% [markdown]
# # **`.sample()`**
#
# The `.sample()` method randomly selects a specified number of rows or elements from a DataFrame or Series. It can be used to create random samples for data analysis, with options to set a random seed for reproducibility.

# %%
df.sample(10) # Gives 10 random rows from the data set
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 208       24.27  2.03    Male    Yes  Sat  Dinner     2             12.14
# 21        20.29  2.75  Female     No  Sat  Dinner     2             10.14
# 162       16.21  2.00  Female     No  Sun  Dinner     3              5.40
# 155       29.85  5.14  Female     No  Sun  Dinner     5              5.97
# 54        25.56  4.34    Male     No  Sun  Dinner     4              6.39
# 20        17.92  4.08    Male     No  Sat  Dinner     2              8.96
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 72        26.86  3.14  Female    Yes  Sat  Dinner     2             13.43
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4              5.79
# 91        22.49  3.50    Male     No  Fri  Dinner     2             11.24
#
#              Payer Name         CC Number Payment ID
# 208        Jason Carter  4268942915626180    Sat6048
# ...

# %%
df.sample(frac=0.1) # Gives a random 10% of the data from the entire data_set
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 233       10.77  1.47    Male     No   Sat  Dinner     2              5.38
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2              6.50
# 127       14.52  2.00  Female     No  Thur   Lunch     2              7.26
# 145        8.35  1.50  Female     No  Thur   Lunch     2              4.18
# 26        13.37  2.00    Male     No   Sat  Dinner     2              6.68
# 200       18.71  4.00    Male    Yes  Thur   Lunch     3              6.24
# 37        16.93  3.07  Female     No   Sat  Dinner     3              5.64
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3              5.49
# 77        27.20  4.00    Male     No  Thur   Lunch     4              6.80
# 76        17.92  3.08    Male    Yes   Sat  Dinner     2              8.96
# ...
